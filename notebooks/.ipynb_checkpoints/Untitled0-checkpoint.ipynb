# %% [markdown]
# #

# %% [markdown]
# ##

# %% [markdown]
# ### Requirements:

# %% [markdown]
# # Learning from 1.1k bugs (part I: setting up the experiments)
#
# ## Introduction
#
# The data used to experiment are the 1.1k bugs genered and submitted to the [Debian](https://bugs.debian.org/cgi-bin/pkgreport.cgi?submitter=alexandre%40cmu.edu)
#
# In order to obtain reproducible results in our experiment, we are going to use [Vagrant](http://www.vagrantup.com/) with a Debian 7.3 preinstaled VM. It has installed almost every package that
#
# As you can imagine, the VM has installed a large number of obscure services (most of them are not configure and broken) as a result of installing all the buggy programs. I turned them off.
